# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

drive_folder_class0 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Malignant/oral squamous cell carcinoma'

drive_folder_class1 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/exo/Oral Fibroma'
drive_folder_class2 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/exo/oral pyogenic granuloma/train'
drive_folder_class3 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/exo/Peripheral giant cell granuloma/train'

drive_folder_class4 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Aphthous Ulcers'
drive_folder_class5 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/fungal infection/Oral Candidiasis'

drive_folder_class7 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Pigmante/Amalgam Tattoo'
drive_folder_class8 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Pigmante/Hairy Tongue'
drive_folder_class9 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Pigmante/oral malignant melanoma'
drive_folder_class10 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Pigmante/oral melanoacanthoma'
drive_folder_class11 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Pigmante/Oral Melanocytic Nevus'
drive_folder_class12 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Pigmante/oral melanotic macule'

drive_folder_class13 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Red and white/erythroplakia'
drive_folder_class14 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Red and white/leukoplakia'
drive_folder_class15 = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_train/Red and white/Oral lichen planus'

#----------------------------------------------------------------------------------------------------------------------------------------------

# drive_folder_class0_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Malignant val/oral squamous cell carcinoma val'

# drive_folder_class1_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/exo val/Oral Fibroma'
# drive_folder_class2_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/exo val/oral pyogenic granuloma'
# drive_folder_class3_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/exo val/Peripheral giant cell granuloma'

# drive_folder_class4_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Aphthous Ulcers val'
# drive_folder_class5_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/fungal infection val/Oral Candidiasis val'

# drive_folder_class7_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Pigmante val/Amalgam Tattoo val'
# drive_folder_class8_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Pigmante val/Hairy Tongue val'
# drive_folder_class9_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Pigmante val/oral malignant melanoma val'
# drive_folder_class10_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Pigmante val/oral melanoacanthoma val'
# drive_folder_class11_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Pigmante val/Oral Melanocytic Nevus val'
# drive_folder_class12_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Pigmante val/oral melanotic macule val'

# drive_folder_class13_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Red and white val/erythroplakia val'
# drive_folder_class14_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Red and white val/leukoplakia val'
# drive_folder_class15_val = '/content/drive/MyDrive/__Dandoon__/Master1.2 modified 2/Lesions_validation/Red and white val/Oral lichen planus val'



yolo_folder = '/content/drive/MyDrive/__Dandoon__/dataset_6classes_Ultimate'    # Destination folder for YOLO

# Create YOLO structure
os.makedirs(os.path.join(yolo_folder, 'images/train'), exist_ok=True)
os.makedirs(os.path.join(yolo_folder, 'labels/train'), exist_ok=True)

# Function to copy and rename files
def organize_class_files(class_folder, class_prefix):
    files = os.listdir(class_folder)

    for file in files:
        file_name, ext = os.path.splitext(file)

        # Path to the corresponding .txt file
        txt_file = os.path.join(class_folder, f"{file_name}.txt")

        # Check if the file is an image (.png, .jpg) and if the corresponding .txt file exists
        if ext in ['.png', '.jpg'] and os.path.exists(txt_file):
            # Generate a new file name with class prefix to avoid conflicts
            new_file_name = f"{class_prefix}_{file_name}{ext}"

            # Copy the image
            shutil.copy(os.path.join(class_folder, file), os.path.join(yolo_folder, 'images/train', new_file_name))

            # Copy the corresponding .txt file
            new_txt_name = f"{class_prefix}_{file_name}.txt"
            shutil.copy(txt_file, os.path.join(yolo_folder, 'labels/train', new_txt_name))

# Organize files from both class folders
organize_class_files(drive_folder_class0, 'class0')
organize_class_files(drive_folder_class1, 'class1')
organize_class_files(drive_folder_class2, 'class2')
organize_class_files(drive_folder_class3, 'class3')
organize_class_files(drive_folder_class4, 'class4')
organize_class_files(drive_folder_class5, 'class5')
organize_class_files(drive_folder_class7, 'class7')
organize_class_files(drive_folder_class8, 'class8')
organize_class_files(drive_folder_class9, 'class9')
organize_class_files(drive_folder_class10, 'class10')
organize_class_files(drive_folder_class11, 'class11')
organize_class_files(drive_folder_class12, 'class12')
organize_class_files(drive_folder_class13, 'class13')
organize_class_files(drive_folder_class14, 'class14')
organize_class_files(drive_folder_class15, 'class15')


# organize_class_files(drive_folder_class0_val, 'class0')
# organize_class_files(drive_folder_class1_val, 'class1')
# organize_class_files(drive_folder_class2_val, 'class2')
# organize_class_files(drive_folder_class3_val, 'class3')
# organize_class_files(drive_folder_class4_val, 'class4')
# organize_class_files(drive_folder_class5_val, 'class5')
# organize_class_files(drive_folder_class7_val, 'class7')
# organize_class_files(drive_folder_class8_val, 'class8')
# organize_class_files(drive_folder_class9_val, 'class9')
# organize_class_files(drive_folder_class10_val, 'class10')
# organize_class_files(drive_folder_class11_val, 'class11')
# organize_class_files(drive_folder_class12_val, 'class12')
# organize_class_files(drive_folder_class13_val, 'class13')
# organize_class_files(drive_folder_class14_val, 'class14')
# organize_class_files(drive_folder_class15_val, 'class15')



print(f"Files have been copied and renamed in {yolo_folder}.")
# Out:
# Files have been copied and renamed in /content/drive/MyDrive/__Dandoon__/dataset_6classes_Ultimate.

# %%
# Define the YAML content for YOLO
yaml_content = f"""
train: {yolo_folder}/images/train  # path to training images
val: {yolo_folder}/images/val      # path to validation images

nc: 6  # number of classes
names: ['Aphthous Ulcers', 'exo', 'fungal infection', 'Malignant', 'Pigmante', 'Red and white']  # list of class names
"""


# Save the YAML file
yaml_path = os.path.join(yolo_folder, 'data.yaml')
with open(yaml_path, 'w') as yaml_file:
    yaml_file.write(yaml_content)

print(f"YAML file created at {yaml_path}.")
# Out:
# YAML file created at /content/drive/MyDrive/__Dandoon__/dataset_6classes_Ultimate/data.yaml.
